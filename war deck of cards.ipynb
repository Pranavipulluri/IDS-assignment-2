# %%
import random
suits= ('Heart','Diamonds', 'clubs', 'Spades')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten','Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}
class card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
    def __str__(self):
        return self.rank + " of " + self.suit
class Deck:
    def __init__(self):
        self.all_cards=[]
        for suit in suits:
            for rank in ranks:
                created_card=card(suit,rank)
                self.all_cards.append(created_card)
    def shuffle(self):
        random.shuffle(self.all_cards)
    def deal_one(self):
        return self.all_cards.pop()
class player():
    def __init__(self,name):
        self.name=name
        self.all_cards = []
    def remove_one(self):
        return self.all_cards.pop(0)
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    def __str__(self):
        return f'player {self.name} has {len(self.all_cards)} cards'
player_one = player("Pranavi")
player_two = player(input("enter your name:"))

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
round_num = 0
def game():
    choice=['Y','N']
    opt=' '
    while opt not in choice:
        opt=input("do u want to start game(Y or N):")
        if opt not in choice:
            print('wrong input enter Y or N in capitals')
    return opt
YN = game()
if YN == 'Y':
    game_on = True
    print("This game truly based on luck so yeah welcome to my war game!!\n")
    print("In this game rounds automatically takes place and when thir is a war it asks for your input\n who ran out of the cards first will loose the game.")
else:
    game_on = False
    print("ok your bad, bye bye!!")
while game_on:
    round_num +=1
    print(f"Round {round_num}")
    
    if len(player_one.all_cards) == 0:
        print('Pranavi out of cards! You won')
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print('you ran out of cards! Pranavi won')
        game_on = False
        break
        
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    n = 100
    
    at_war = True
    while at_war:
        if player_one_cards[-1].value>player_two_cards[-1].value:
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            print("you lost your cards in this round")
            
            at_war = False
            
        elif player_one_cards[-1].value<player_two_cards[-1].value:
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            print("you gained cards in this round")
            
            at_war = False
        else:
            print('WAR!')
            def cards():
                x = []
                for n in range(1,27):
                    x.append(n)
                m = int(input("enter how many cards you want to declare war:"))
                while m not in x:
                    m = int(input("enter how many cards you want to declare war:"))
                    if m not in x:
                        print("wrong input enter in between 1 to 26")
                return m
            y = cards()
            if len(player_one.all_cards) < y:
                print("Pranavi unable to declare war")
                print("You won!")
                game_on = False
                break
            elif len(player_two.all_cards) < y:
                print("you are unable to declare war")
                print("pranavi won!")
                game_on = False
                break
            else:
                for num in range(y):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
                    
            at_war = True
# Out:
# enter your name:sonu
# do u want to start game(Y or N):Y
# This game truly based on luck so yeah welcome to my war game!!
#
# In this game rounds automatically takes place and when thir is a war it asks for your input
#  who ran out of the cards first will loose the game.
# Round 1
# you lost your cards in this round
# Round 2
# you gained cards in this round
# Round 3
# you gained cards in this round
# Round 4
# you gained cards in this round
# Round 5
# you gained cards in this round
# Round 6
# you lost your cards in this round
# Round 7
# you lost your cards in this round
# Round 8
# you lost your cards in this round
# Round 9
# you gained cards in this round
# Round 10
# you gained cards in this round
# Round 11
# you lost your cards in this round
# Round 12
# you gained cards in this round
# Round 13
# you gained cards in this round
# Round 14
# WAR!
# enter how many cards you want to declare war:26
# Pranavi unable to declare war
# You won!
